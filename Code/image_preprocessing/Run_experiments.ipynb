# %% [markdown]
# # Preprocessing DL
# ## Replicating Hao's experiments

# %% [markdown]
# ### 0. Before Starting.
#
# One need to create a Conda environment with python 2.7 and install the corresponding version of Clinica inside:

# %% [markdown]
# ```bash
# conda create --name clinica_dl_pre_py27 python=2.7
# conda activate clinica_dl_pre_py27
# conda install -c aramislab -c conda-forge clinica=0.1.3
# pip install -r requirements.txt
# conda install pytorch-cpu torchvision-cpu -c pytorch
# # conda install pytorch torchvision -c pytorch //for macOS
# conda install jupyter
# ```

# %% [markdown]
# ### 1. Preprocessing, first part.
#
# Running the first part of preprocessing (inspired from `run_preprocessing.py`).
#
# Defining data folders:

# %%
bids_directory = '/Users/mauricio.diazmelo/tmp/DL/ADNI_BIDS_T1_new'
caps_directory= '/Users/mauricio.diazmelo/tmp/DL/ADNI_CAPS'
tsv = '/Users/mauricio.diazmelo/tmp/DL/image_preprocessing_test.tsv'
working_dir = '/Users/mauricio.diazmelo/tmp/DL/working_dir'
ref_template = '/Users/mauricio.diazmelo/tmp/DL/mni_icbm152_nlin_sym_09c_nifti/mni_icbm152_nlin_sym_09c/mni_icbm152_t1_tal_nlin_sym_09c.nii'

# %% [markdown]
# Import module for `T1_preprocessing`:

# %%
from T1_preprocessing import preprocessing_t1w

wf = preprocessing_t1w(bids_directory, caps_directory, tsv, ref_template, working_directory=working_dir)
#wf.write_graph("workflow_graph.dot")
#wf.write_graph(graph2use='flat')
wf.run(plugin='MultiProc', plugin_args={'n_procs': 4})
# Out:
# 190502-18:38:31,853 workflow INFO:
# 	 ['check', 'execution', 'logging']
# 190502-18:38:31,877 workflow INFO:
# 	 Running in parallel.
# 190502-18:38:31,892 workflow INFO:
# 	 Executing: get_subject_session_list ID: 0
# 190502-18:38:31,900 workflow INFO:
# 	 Executing node get_subject_session_list in dir: /Users/mauricio.diazmelo/tmp/DL/working_dir/t1w_preprocessing_dl/get_subject_session_list
# 190502-18:38:32,942 workflow INFO:
# 	 Runtime memory and threads stats unavailable
# 190502-18:38:32,955 workflow INFO:
# 	 [Job finished] jobname: get_subject_session_list jobid: 0
# 190502-18:38:32,966 workflow INFO:
# 	 Executing: datagrabbernode ID: 1
# 190502-18:38:32,999 workflow INFO:
# 	 Executing: get_subid_sesid_datasink ID: 2
# 190502-18:38:33,3 workflow INFO:
# 	 Executing node datagrabbernode in dir: /Users/mauricio.diazmelo/tmp/DL/working_dir/t1w_preprocessing_dl/datagrabbernode
# 190502-18:38:33,42 workflow INFO:
# 	 Adding 2 jobs for mapnode get_subid_sesid_datasink
# 190502-18:38:33,52 workflow INFO:
# 	 Executing: rename_file ID: 3
# 190502-18:38:33,102 workflow INFO:
# 	 Adding 2 jobs for mapnode rename_file
# 190502-18:38:33,135 workflow INFO:
# 	 Executing: _get_subid_sesid_datasink0 ID: 9
# 190502-18:38:33,163 workflow INFO:
# 	 Executing: _get_subid_sesid_datasink1 ID: 10
# 190502-18:38:33,167 workflow INFO:
# 	 Executing node _get_subid_sesid_datasink0 in dir: /Users/mauricio.diazmelo/tmp/DL/working_dir/t1w_preprocessing_dl/get_subid_sesid_datasink/mapflow/_get_subid_sesid_datasink0
# 190502-18:38:33,180 workflow INFO:
# 	 Executing: _rename_file0 ID: 11
# 190502-18:38:33,185 workflow INFO:
# 	 Executing node _get_subid_sesid_datasink1 in dir: /Users/mauricio.diazmelo/tmp/DL/working_dir/t1w_preprocessing_dl/get_subid_sesid_datasink/mapflow/_get_subid_sesid_datasink1
# 190502-18:38:33,197 workflow INFO:
# 	 Executing node _rename_file0 in dir: /Users/mauricio.diazmelo/tmp/DL/working_dir/t1w_preprocessing_dl/rename_file/mapflow/_rename_file0
# 190502-18:38:33,314 workflow INFO:
# 	 Runtime memory and threads stats unavailable
# 190502-18:38:33,335 workflow INFO:
# 	 [Job finished] jobname: _rename_file0 jobid: 11
# 190502-18:38:33,365 workflow INFO:
# 	 Executing: _rename_file1 ID: 12
# 190502-18:38:33,379 workflow INFO:
# 	 Executing node _rename_file1 in dir: /Users/mauricio.diazmelo/tmp/DL/working_dir/t1w_preprocessing_dl/rename_file/mapflow/_rename_file1
# /Users/mauricio.diazmelo/miniconda3/envs/clinica_dl_pre_py27/lib/python2.7/site-packages/grabbit/core.py:410: UserWarning: No valid root directory found for domain 'derivatives'. Falling back on the Layout's root directory. If this isn't the intended behavior, make sure the config file for this domain includes a 'root' key.
#   "'root' key." % config['name'])
# 190502-18:38:33,407 workflow INFO:
# 	 Runtime memory and threads stats unavailable
# 190502-18:38:33,417 workflow INFO:
# 	 Runtime memory and threads stats unavailable
# 190502-18:38:33,461 workflow INFO:
# 	 [Job finished] jobname: _get_subid_sesid_datasink0 jobid: 9
# 190502-18:38:33,463 workflow INFO:
# 	 [Job finished] jobname: _get_subid_sesid_datasink1 jobid: 10
# 190502-18:38:33,469 workflow INFO:
# 	 Executing: get_subid_sesid_datasink ID: 2
# 190502-18:38:33,492 workflow INFO:
# 	 Executing node get_subid_sesid_datasink in dir: /Users/mauricio.diazmelo/tmp/DL/working_dir/t1w_preprocessing_dl/get_subid_sesid_datasink
# 190502-18:38:33,535 workflow INFO:
# 	 Runtime memory and threads stats unavailable
# 190502-18:38:33,567 workflow INFO:
# 	 [Job finished] jobname: _rename_file1 jobid: 12
# 190502-18:38:33,592 workflow INFO:
# 	 Executing: rename_file ID: 3
# 190502-18:38:33,584 workflow INFO:
# 	 Executing node _get_subid_sesid_datasink0 in dir: /Users/mauricio.diazmelo/tmp/DL/working_dir/t1w_preprocessing_dl/get_subid_sesid_datasink/mapflow/_get_subid_sesid_datasink0
# 190502-18:38:33,602 workflow INFO:
# 	 Executing node rename_file in dir: /Users/mauricio.diazmelo/tmp/DL/working_dir/t1w_preprocessing_dl/rename_file
# 190502-18:38:33,630 workflow INFO:
# 	 Executing node _rename_file0 in dir: /Users/mauricio.diazmelo/tmp/DL/working_dir/t1w_preprocessing_dl/rename_file/mapflow/_rename_file0
# @clinica@There is just one run for T1w image of this analysis
# 190502-18:38:33,648 workflow INFO:
# 	 Collecting precomputed outputs
#
# 190502-18:38:33,658 workflow INFO:
# 	 Collecting precomputed outputs
# @clinica@GREAT
#
# @clinica@GREAT
# 190502-18:38:33,670 workflow INFO:
# 	 Executing node _rename_file1 in dir: /Users/mauricio.diazmelo/tmp/DL/working_dir/t1w_preprocessing_dl/rename_file/mapflow/_rename_file1
# 190502-18:38:33,713 workflow INFO:
# 	 Executing node _get_subid_sesid_datasink1 in dir: /Users/mauricio.diazmelo/tmp/DL/working_dir/t1w_preprocessing_dl/get_subid_sesid_datasink/mapflow/_get_subid_sesid_datasink1
# 190502-18:38:33,714 workflow INFO:
# 	 Collecting precomputed outputs
#
# 190502-18:38:33,718 workflow INFO:
# 	 Collecting precomputed outputs
# 190502-18:38:33,745 workflow INFO:
# 	 Runtime memory and threads stats unavailable
# 190502-18:38:33,776 workflow INFO:
# 	 [Job finished] jobname: rename_file jobid: 3
# 190502-18:38:33,822 workflow INFO:
# 	 [Job finished] jobname: datagrabbernode jobid: 1
# 190502-18:38:33,825 workflow INFO:
# 	 [Job finished] jobname: get_subid_sesid_datasink jobid: 2
# 190502-18:38:33,859 workflow INFO:
# 	 Executing: n4biascorrection ID: 4
# 190502-18:38:33,905 workflow INFO:
# 	 Adding 2 jobs for mapnode n4biascorrection
# 190502-18:38:33,917 workflow INFO:
# 	 Executing: _n4biascorrection0 ID: 13
# 190502-18:38:33,920 workflow INFO:
# 	 Executing: _n4biascorrection1 ID: 14
# 190502-18:38:33,922 workflow INFO:
# 	 Executing node _n4biascorrection0 in dir: /Users/mauricio.diazmelo/tmp/DL/working_dir/t1w_preprocessing_dl/n4biascorrection/mapflow/_n4biascorrection0
# 190502-18:38:33,928 workflow INFO:
# 	 Executing node _n4biascorrection1 in dir: /Users/mauricio.diazmelo/tmp/DL/working_dir/t1w_preprocessing_dl/n4biascorrection/mapflow/_n4biascorrection1
# 190502-18:38:33,951 workflow INFO:
# 	 Running: N4BiasFieldCorrection --bspline-fitting [ 600 ] -d 3 --input-image /Users/mauricio.diazmelo/tmp/DL/ADNI_BIDS_T1_new/sub-ADNI022S0004/ses-M00/anat/sub-ADNI022S0004_ses-M00_T1w.nii.gz --output [ sub-ADNI022S0004_ses-M00.nii.gz, sub-ADNI022S0004_ses-M00_T1w_bias.nii.gz ]
# 190502-18:38:33,959 workflow INFO:
# 	 Running: N4BiasFieldCorrection --bspline-fitting [ 600 ] -d 3 --input-image /Users/mauricio.diazmelo/tmp/DL/ADNI_BIDS_T1_new/sub-ADNI100S0006/ses-M00/anat/sub-ADNI100S0006_ses-M00_T1w.nii.gz --output [ sub-ADNI100S0006_ses-M00.nii.gz, sub-ADNI100S0006_ses-M00_T1w_bias.nii.gz ]
# 190502-18:41:45,547 workflow INFO:
# 	 [Job finished] jobname: _n4biascorrection0 jobid: 13
# 190502-18:43:48,875 workflow INFO:
# 	 [Job finished] jobname: _n4biascorrection1 jobid: 14
# 190502-18:43:48,890 workflow INFO:
# 	 Executing: n4biascorrection ID: 4
# 190502-18:43:48,917 workflow INFO:
# 	 Executing node n4biascorrection in dir: /Users/mauricio.diazmelo/tmp/DL/working_dir/t1w_preprocessing_dl/n4biascorrection
# 190502-18:43:48,966 workflow INFO:
# 	 Executing node _n4biascorrection0 in dir: /Users/mauricio.diazmelo/tmp/DL/working_dir/t1w_preprocessing_dl/n4biascorrection/mapflow/_n4biascorrection0
# 190502-18:43:48,985 workflow INFO:
# 	 Collecting precomputed outputs
# 190502-18:43:49,13 workflow INFO:
# 	 Executing node _n4biascorrection1 in dir: /Users/mauricio.diazmelo/tmp/DL/working_dir/t1w_preprocessing_dl/n4biascorrection/mapflow/_n4biascorrection1
# 190502-18:43:49,25 workflow INFO:
# 	 Collecting precomputed outputs
# 190502-18:43:49,69 workflow INFO:
# 	 [Job finished] jobname: n4biascorrection jobid: 4
# 190502-18:43:49,82 workflow INFO:
# 	 Executing: antsRegistrationSyNQuick ID: 5
# 190502-18:43:49,117 workflow INFO:
# 	 Adding 2 jobs for mapnode antsRegistrationSyNQuick
# 190502-18:43:49,124 workflow INFO:
# 	 Executing: _antsRegistrationSyNQuick0 ID: 15
# 190502-18:43:49,127 workflow INFO:
# 	 Executing: _antsRegistrationSyNQuick1 ID: 16
# 190502-18:43:49,134 workflow INFO:
# 	 Executing node _antsRegistrationSyNQuick0 in dir: /Users/mauricio.diazmelo/tmp/DL/working_dir/t1w_preprocessing_dl/antsRegistrationSyNQuick/mapflow/_antsRegistrationSyNQuick0
# 190502-18:43:49,136 workflow INFO:
# 	 Executing node _antsRegistrationSyNQuick1 in dir: /Users/mauricio.diazmelo/tmp/DL/working_dir/t1w_preprocessing_dl/antsRegistrationSyNQuick/mapflow/_antsRegistrationSyNQuick1
# 190502-18:47:08,954 workflow INFO:
# 	 Runtime memory and threads stats unavailable
# 190502-18:47:08,967 workflow INFO:
# 	 [Job finished] jobname: _antsRegistrationSyNQuick0 jobid: 15
# 190502-18:47:40,94 workflow INFO:
# 	 Runtime memory and threads stats unavailable
# 190502-18:47:40,107 workflow INFO:
# 	 [Job finished] jobname: _antsRegistrationSyNQuick1 jobid: 16
# 190502-18:47:40,111 workflow INFO:
# 	 Executing: antsRegistrationSyNQuick ID: 5
# 190502-18:47:40,121 workflow INFO:
# 	 Executing node antsRegistrationSyNQuick in dir: /Users/mauricio.diazmelo/tmp/DL/working_dir/t1w_preprocessing_dl/antsRegistrationSyNQuick
# 190502-18:47:40,143 workflow INFO:
# 	 Executing node _antsRegistrationSyNQuick0 in dir: /Users/mauricio.diazmelo/tmp/DL/working_dir/t1w_preprocessing_dl/antsRegistrationSyNQuick/mapflow/_antsRegistrationSyNQuick0
# 190502-18:47:40,152 workflow INFO:
# 	 Collecting precomputed outputs
# 190502-18:47:40,165 workflow INFO:
# 	 Executing node _antsRegistrationSyNQuick1 in dir: /Users/mauricio.diazmelo/tmp/DL/working_dir/t1w_preprocessing_dl/antsRegistrationSyNQuick/mapflow/_antsRegistrationSyNQuick1
# 190502-18:47:40,173 workflow INFO:
# 	 Collecting precomputed outputs
# 190502-18:47:40,199 workflow INFO:
# 	 [Job finished] jobname: antsRegistrationSyNQuick jobid: 5
# 190502-18:47:40,206 workflow INFO:
# 	 Executing: cropnifti ID: 6
# 190502-18:47:40,217 workflow INFO:
# 	 Adding 2 jobs for mapnode cropnifti
# 190502-18:47:40,223 workflow INFO:
# 	 Executing: _cropnifti0 ID: 17
# 190502-18:47:40,227 workflow INFO:
# 	 Executing: _cropnifti1 ID: 18
# 190502-18:47:40,228 workflow INFO:
# 	 Executing node _cropnifti0 in dir: /Users/mauricio.diazmelo/tmp/DL/working_dir/t1w_preprocessing_dl/cropnifti/mapflow/_cropnifti0
# 190502-18:47:40,233 workflow INFO:
# 	 Executing node _cropnifti1 in dir: /Users/mauricio.diazmelo/tmp/DL/working_dir/t1w_preprocessing_dl/cropnifti/mapflow/_cropnifti1
# /Users/mauricio.diazmelo/miniconda3/envs/clinica_dl_pre_py27/lib/python2.7/site-packages/nilearn/image/image.py:303: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   cropped_data = data[slices]
# /Users/mauricio.diazmelo/miniconda3/envs/clinica_dl_pre_py27/lib/python2.7/site-packages/nilearn/image/image.py:303: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   cropped_data = data[slices]
# /Users/mauricio.diazmelo/miniconda3/envs/clinica_dl_pre_py27/lib/python2.7/site-packages/scipy/ndimage/interpolation.py:472: UserWarning: The behaviour of affine_transform with a one-dimensional array supplied for the matrix parameter has changed in scipy 0.18.0.
#   "The behaviour of affine_transform with a one-dimensional "
# /Users/mauricio.diazmelo/miniconda3/envs/clinica_dl_pre_py27/lib/python2.7/site-packages/scipy/ndimage/interpolation.py:472: UserWarning: The behaviour of affine_transform with a one-dimensional array supplied for the matrix parameter has changed in scipy 0.18.0.
#   "The behaviour of affine_transform with a one-dimensional "
# 190502-18:47:49,918 workflow INFO:
# 	 Runtime memory and threads stats unavailable
# 190502-18:47:49,933 workflow INFO:
# 	 [Job finished] jobname: _cropnifti0 jobid: 17
# 190502-18:47:49,942 workflow INFO:
# 	 Runtime memory and threads stats unavailable
# 190502-18:47:49,953 workflow INFO:
# 	 [Job finished] jobname: _cropnifti1 jobid: 18
# 190502-18:47:49,957 workflow INFO:
# 	 Executing: cropnifti ID: 6
# 190502-18:47:49,963 workflow INFO:
# 	 Executing node cropnifti in dir: /Users/mauricio.diazmelo/tmp/DL/working_dir/t1w_preprocessing_dl/cropnifti
# 190502-18:47:49,983 workflow INFO:
# 	 Executing node _cropnifti0 in dir: /Users/mauricio.diazmelo/tmp/DL/working_dir/t1w_preprocessing_dl/cropnifti/mapflow/_cropnifti0
# 190502-18:47:49,993 workflow INFO:
# 	 Collecting precomputed outputs
# 190502-18:47:50,7 workflow INFO:
# 	 Executing node _cropnifti1 in dir: /Users/mauricio.diazmelo/tmp/DL/working_dir/t1w_preprocessing_dl/cropnifti/mapflow/_cropnifti1
# 190502-18:47:50,16 workflow INFO:
# 	 Collecting precomputed outputs
# 190502-18:47:50,42 workflow INFO:
# 	 [Job finished] jobname: cropnifti jobid: 6
# 190502-18:47:50,48 workflow INFO:
# 	 Executing: intensitynormalization ID: 7
# 190502-18:47:50,66 workflow INFO:
# 	 Adding 2 jobs for mapnode intensitynormalization
# 190502-18:47:50,72 workflow INFO:
# 	 Executing: _intensitynormalization0 ID: 19
# 190502-18:47:50,75 workflow INFO:
# 	 Executing: _intensitynormalization1 ID: 20
# 190502-18:47:50,76 workflow INFO:
# 	 Executing node _intensitynormalization0 in dir: /Users/mauricio.diazmelo/tmp/DL/working_dir/t1w_preprocessing_dl/intensitynormalization/mapflow/_intensitynormalization0
# 190502-18:47:50,81 workflow INFO:
# 	 Executing node _intensitynormalization1 in dir: /Users/mauricio.diazmelo/tmp/DL/working_dir/t1w_preprocessing_dl/intensitynormalization/mapflow/_intensitynormalization1
# 190502-18:47:53,741 workflow INFO:
# 	 Runtime memory and threads stats unavailable
# 190502-18:47:53,758 workflow INFO:
# 	 [Job finished] jobname: _intensitynormalization1 jobid: 20
# 190502-18:47:53,765 workflow INFO:
# 	 Runtime memory and threads stats unavailable
# 190502-18:47:53,774 workflow INFO:
# 	 [Job finished] jobname: _intensitynormalization0 jobid: 19
# 190502-18:47:53,778 workflow INFO:
# 	 Executing: intensitynormalization ID: 7
# 190502-18:47:53,785 workflow INFO:
# 	 Executing node intensitynormalization in dir: /Users/mauricio.diazmelo/tmp/DL/working_dir/t1w_preprocessing_dl/intensitynormalization
# 190502-18:47:53,806 workflow INFO:
# 	 Executing node _intensitynormalization0 in dir: /Users/mauricio.diazmelo/tmp/DL/working_dir/t1w_preprocessing_dl/intensitynormalization/mapflow/_intensitynormalization0
# 190502-18:47:53,812 workflow INFO:
# 	 Collecting precomputed outputs
# 190502-18:47:53,824 workflow INFO:
# 	 Executing node _intensitynormalization1 in dir: /Users/mauricio.diazmelo/tmp/DL/working_dir/t1w_preprocessing_dl/intensitynormalization/mapflow/_intensitynormalization1
# 190502-18:47:53,830 workflow INFO:
# 	 Collecting precomputed outputs
# 190502-18:47:53,856 workflow INFO:
# 	 [Job finished] jobname: intensitynormalization jobid: 7
# 190502-18:47:53,861 workflow INFO:
# 	 Executing: datasinker ID: 8
# 190502-18:47:53,921 workflow INFO:
# 	 Adding 2 jobs for mapnode datasinker
# 190502-18:47:53,927 workflow INFO:
# 	 Executing: _datasinker0 ID: 21
# 190502-18:47:53,933 workflow INFO:
# 	 Executing: _datasinker1 ID: 22
# 190502-18:47:53,936 workflow INFO:
# 	 Executing node _datasinker0 in dir: /Users/mauricio.diazmelo/tmp/DL/working_dir/t1w_preprocessing_dl/datasinker/mapflow/_datasinker0
# 190502-18:47:53,946 workflow INFO:
# 	 Executing node _datasinker1 in dir: /Users/mauricio.diazmelo/tmp/DL/working_dir/t1w_preprocessing_dl/datasinker/mapflow/_datasinker1
# 190502-18:47:53,970 interface INFO:
# 	 sub: /Users/mauricio.diazmelo/tmp/DL/ADNI_CAPS/subjects/sub-ADNI022S0004/ses-M00/t1/preprocessing_dl/trait_added/_datasinker0/out_file_reg -> /Users/mauricio.diazmelo/tmp/DL/ADNI_CAPS/subjects/sub-ADNI022S0004/ses-M00/t1/preprocessing_dl/out_file_reg
# 190502-18:47:53,978 interface INFO:
# 	 sub: /Users/mauricio.diazmelo/tmp/DL/ADNI_CAPS/subjects/sub-ADNI022S0004/ses-M00/t1/preprocessing_dl/out_file_reg/_antsRegistrationSyNQuick0/sub-ADNI022S0004_ses-M00_SyN_QuickWarped.nii.gz -> /Users/mauricio.diazmelo/tmp/DL/ADNI_CAPS/subjects/sub-ADNI022S0004/ses-M00/t1/preprocessing_dl/sub-ADNI022S0004_ses-M00_space-MNI_res-1x1x1_linear_registration.nii.gz
# 190502-18:47:53,982 interface INFO:
# 	 sub: /Users/mauricio.diazmelo/tmp/DL/ADNI_CAPS/subjects/sub-ADNI100S0006/ses-M00/t1/preprocessing_dl/trait_added/_datasinker1/out_file_reg -> /Users/mauricio.diazmelo/tmp/DL/ADNI_CAPS/subjects/sub-ADNI100S0006/ses-M00/t1/preprocessing_dl/out_file_reg
# 190502-18:47:53,984 interface INFO:
# 	 sub: /Users/mauricio.diazmelo/tmp/DL/ADNI_CAPS/subjects/sub-ADNI100S0006/ses-M00/t1/preprocessing_dl/out_file_reg/_antsRegistrationSyNQuick1/sub-ADNI100S0006_ses-M00_SyN_QuickWarped.nii.gz -> /Users/mauricio.diazmelo/tmp/DL/ADNI_CAPS/subjects/sub-ADNI100S0006/ses-M00/t1/preprocessing_dl/sub-ADNI100S0006_ses-M00_space-MNI_res-1x1x1_linear_registration.nii.gz
# 190502-18:47:54,259 interface INFO:
# 	 sub: /Users/mauricio.diazmelo/tmp/DL/ADNI_CAPS/subjects/sub-ADNI100S0006/ses-M00/t1/preprocessing_dl/out_file_inn/_intensitynormalization1/sub-ADNI100S0006_ses-M00_SyN_QuickWarped_cropped_intensity_norm.nii.gz -> /Users/mauricio.diazmelo/tmp/DL/ADNI_CAPS/subjects/sub-ADNI100S0006/ses-M00/t1/preprocessing_dl/sub-ADNI100S0006_ses-M00_space-MNI_res-1x1x1_intensity_norm.nii.gz
# 190502-18:47:54,267 interface INFO:
# 	 sub: /Users/mauricio.diazmelo/tmp/DL/ADNI_CAPS/subjects/sub-ADNI022S0004/ses-M00/t1/preprocessing_dl/out_file_inn/_intensitynormalization0/sub-ADNI022S0004_ses-M00_SyN_QuickWarped_cropped_intensity_norm.nii.gz -> /Users/mauricio.diazmelo/tmp/DL/ADNI_CAPS/subjects/sub-ADNI022S0004/ses-M00/t1/preprocessing_dl/sub-ADNI022S0004_ses-M00_space-MNI_res-1x1x1_intensity_norm.nii.gz
# 190502-18:47:54,440 interface INFO:
# 	 sub: /Users/mauricio.diazmelo/tmp/DL/ADNI_CAPS/subjects/sub-ADNI022S0004/ses-M00/t1/preprocessing_dl/out_file_crop/_cropnifti0/sub-ADNI022S0004_ses-M00_SyN_QuickWarped_cropped.nii.gz -> /Users/mauricio.diazmelo/tmp/DL/ADNI_CAPS/subjects/sub-ADNI022S0004/ses-M00/t1/preprocessing_dl/sub-ADNI022S0004_ses-M00_space-MNI_res-1x1x1.nii.gz
# 190502-18:47:54,460 interface INFO:
# 	 sub: /Users/mauricio.diazmelo/tmp/DL/ADNI_CAPS/subjects/sub-ADNI100S0006/ses-M00/t1/preprocessing_dl/out_file_crop/_cropnifti1/sub-ADNI100S0006_ses-M00_SyN_QuickWarped_cropped.nii.gz -> /Users/mauricio.diazmelo/tmp/DL/ADNI_CAPS/subjects/sub-ADNI100S0006/ses-M00/t1/preprocessing_dl/sub-ADNI100S0006_ses-M00_space-MNI_res-1x1x1.nii.gz
# 190502-18:47:54,733 workflow INFO:
# 	 Runtime memory and threads stats unavailable
# 190502-18:47:54,744 workflow INFO:
# 	 [Job finished] jobname: _datasinker0 jobid: 21
# 190502-18:47:54,758 workflow INFO:
# 	 Runtime memory and threads stats unavailable
# 190502-18:47:54,769 workflow INFO:
# 	 [Job finished] jobname: _datasinker1 jobid: 22
# 190502-18:47:54,774 workflow INFO:
# 	 Executing: datasinker ID: 8
# 190502-18:47:54,796 workflow INFO:
# 	 Executing node datasinker in dir: /Users/mauricio.diazmelo/tmp/DL/working_dir/t1w_preprocessing_dl/datasinker
# 190502-18:47:54,827 workflow INFO:
# 	 Executing node _datasinker0 in dir: /Users/mauricio.diazmelo/tmp/DL/working_dir/t1w_preprocessing_dl/datasinker/mapflow/_datasinker0
# 190502-18:47:54,858 interface INFO:
# 	 sub: /Users/mauricio.diazmelo/tmp/DL/ADNI_CAPS/subjects/sub-ADNI022S0004/ses-M00/t1/preprocessing_dl/trait_added/_datasinker0/out_file_reg -> /Users/mauricio.diazmelo/tmp/DL/ADNI_CAPS/subjects/sub-ADNI022S0004/ses-M00/t1/preprocessing_dl/out_file_reg
# 190502-18:47:54,864 interface INFO:
# 	 sub: /Users/mauricio.diazmelo/tmp/DL/ADNI_CAPS/subjects/sub-ADNI022S0004/ses-M00/t1/preprocessing_dl/out_file_reg/_antsRegistrationSyNQuick0/sub-ADNI022S0004_ses-M00_SyN_QuickWarped.nii.gz -> /Users/mauricio.diazmelo/tmp/DL/ADNI_CAPS/subjects/sub-ADNI022S0004/ses-M00/t1/preprocessing_dl/sub-ADNI022S0004_ses-M00_space-MNI_res-1x1x1_linear_registration.nii.gz
# 190502-18:47:54,872 interface INFO:
# 	 sub: /Users/mauricio.diazmelo/tmp/DL/ADNI_CAPS/subjects/sub-ADNI022S0004/ses-M00/t1/preprocessing_dl/out_file_inn/_intensitynormalization0/sub-ADNI022S0004_ses-M00_SyN_QuickWarped_cropped_intensity_norm.nii.gz -> /Users/mauricio.diazmelo/tmp/DL/ADNI_CAPS/subjects/sub-ADNI022S0004/ses-M00/t1/preprocessing_dl/sub-ADNI022S0004_ses-M00_space-MNI_res-1x1x1_intensity_norm.nii.gz
# 190502-18:47:54,878 interface INFO:
# 	 sub: /Users/mauricio.diazmelo/tmp/DL/ADNI_CAPS/subjects/sub-ADNI022S0004/ses-M00/t1/preprocessing_dl/out_file_crop/_cropnifti0/sub-ADNI022S0004_ses-M00_SyN_QuickWarped_cropped.nii.gz -> /Users/mauricio.diazmelo/tmp/DL/ADNI_CAPS/subjects/sub-ADNI022S0004/ses-M00/t1/preprocessing_dl/sub-ADNI022S0004_ses-M00_space-MNI_res-1x1x1.nii.gz
# 190502-18:47:54,896 workflow INFO:
# 	 Runtime memory and threads stats unavailable
# 190502-18:47:54,911 workflow INFO:
# 	 Executing node _datasinker1 in dir: /Users/mauricio.diazmelo/tmp/DL/working_dir/t1w_preprocessing_dl/datasinker/mapflow/_datasinker1
# 190502-18:47:54,940 interface INFO:
# 	 sub: /Users/mauricio.diazmelo/tmp/DL/ADNI_CAPS/subjects/sub-ADNI100S0006/ses-M00/t1/preprocessing_dl/trait_added/_datasinker1/out_file_reg -> /Users/mauricio.diazmelo/tmp/DL/ADNI_CAPS/subjects/sub-ADNI100S0006/ses-M00/t1/preprocessing_dl/out_file_reg
# 190502-18:47:54,949 interface INFO:
# 	 sub: /Users/mauricio.diazmelo/tmp/DL/ADNI_CAPS/subjects/sub-ADNI100S0006/ses-M00/t1/preprocessing_dl/out_file_reg/_antsRegistrationSyNQuick1/sub-ADNI100S0006_ses-M00_SyN_QuickWarped.nii.gz -> /Users/mauricio.diazmelo/tmp/DL/ADNI_CAPS/subjects/sub-ADNI100S0006/ses-M00/t1/preprocessing_dl/sub-ADNI100S0006_ses-M00_space-MNI_res-1x1x1_linear_registration.nii.gz
# 190502-18:47:54,957 interface INFO:
# 	 sub: /Users/mauricio.diazmelo/tmp/DL/ADNI_CAPS/subjects/sub-ADNI100S0006/ses-M00/t1/preprocessing_dl/out_file_inn/_intensitynormalization1/sub-ADNI100S0006_ses-M00_SyN_QuickWarped_cropped_intensity_norm.nii.gz -> /Users/mauricio.diazmelo/tmp/DL/ADNI_CAPS/subjects/sub-ADNI100S0006/ses-M00/t1/preprocessing_dl/sub-ADNI100S0006_ses-M00_space-MNI_res-1x1x1_intensity_norm.nii.gz
# 190502-18:47:54,965 interface INFO:
# 	 sub: /Users/mauricio.diazmelo/tmp/DL/ADNI_CAPS/subjects/sub-ADNI100S0006/ses-M00/t1/preprocessing_dl/out_file_crop/_cropnifti1/sub-ADNI100S0006_ses-M00_SyN_QuickWarped_cropped.nii.gz -> /Users/mauricio.diazmelo/tmp/DL/ADNI_CAPS/subjects/sub-ADNI100S0006/ses-M00/t1/preprocessing_dl/sub-ADNI100S0006_ses-M00_space-MNI_res-1x1x1.nii.gz
# 190502-18:47:54,983 workflow INFO:
# 	 Runtime memory and threads stats unavailable
# 190502-18:47:55,13 workflow INFO:
# 	 [Job finished] jobname: datasinker jobid: 8

# %% [markdown]
# ### 2. Preprocessing, second part

# %% [markdown]
# Run the second part of preprocessing (inspired from `run_postprocessing_adni.py`).

# %%
from T1_postprocessing import postprocessing_t1w

patch_size = 50
stride_size = 50

# for rgb tf learning
wf2 = postprocessing_t1w(caps_directory, tsv, patch_size, stride_size, working_directory=working_dir, extract_method='slice', slice_mode='rgb')
wf2.run(plugin='MultiProc', plugin_args={'n_procs': 4})

# %%
## for patch
wf3 = postprocessing_t1w(caps_directory, tsv, patch_size, stride_size, working_directory=working_dir, extract_method='patch')
#wf3.write_graph("workflow_graph.dot")
#wf3.write_graph(graph2use='flat')
wf3.run(plugin='MultiProc', plugin_args={'n_procs': 4})
